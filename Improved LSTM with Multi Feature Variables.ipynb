# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

code = 'sh.600036'
new_df = pd.read_csv(f'{code}_history_data.csv', index_col=0)
new_df['EMA_9'] = new_df['close'].ewm(9).mean().shift()
new_df['SMA_5'] = new_df['close'].rolling(5).mean().shift()
new_df['SMA_10'] = new_df['close'].rolling(10).mean().shift()
new_df['SMA_15'] = new_df['close'].rolling(15).mean().shift()
new_df['SMA_30'] = new_df['close'].rolling(30).mean().shift()

def calculate_macd(data, short_period, long_period, signal_period):
    short_ema = data.ewm(span=short_period, adjust=False).mean()
    long_ema = data.ewm(span=long_period, adjust=False).mean()
    macd_line = short_ema - long_ema
    signal_line = macd_line.ewm(span=signal_period, adjust=False).mean()
    return macd_line, signal_line

def calculate_rsi(data, period):
    delta = data.diff()
    gains = delta.where(delta > 0, 0)
    losses = -delta.where(delta < 0, 0)
    
    avg_gain = gains.rolling(window=period, min_periods=1).mean()
    avg_loss = losses.rolling(window=period, min_periods=1).mean()
    
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def calculate_wpr(data, period):
    highest_high = data.rolling(window=period, min_periods=1).max()
    lowest_low = data.rolling(window=period, min_periods=1).min()
    wpr = (highest_high - data) / (highest_high - lowest_low) * -100
    return wpr

# Calculate MACD
short_period = 12
long_period = 26
signal_period = 9
new_df['MACD'], new_df['Signal_Line'] = calculate_macd(new_df['close'], short_period, long_period, signal_period)

# Calculate RSI
rsi_period = 14
new_df['RSI'] = calculate_rsi(new_df['close'], rsi_period)

# Calculate WPR
wpr_period = 14
new_df['WPR'] = calculate_wpr(new_df['close'], wpr_period)

print(new_df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\HuaweiMoveData\Users\abc\Desktop\LSTM-XGBoost招商银行.ipynb 单元格 1 line 4
#       <a href='vscode-notebook-cell:/d%3A/HuaweiMoveData/Users/abc/Desktop/LSTM-XGBoost%E6%8B%9B%E5%95%86%E9%93%B6%E8%A1%8C.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/d%3A/HuaweiMoveData/Users/abc/Desktop/LSTM-XGBoost%E6%8B%9B%E5%95%86%E9%93%B6%E8%A1%8C.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/d%3A/HuaweiMoveData/Users/abc/Desktop/LSTM-XGBoost%E6%8B%9B%E5%95%86%E9%93%B6%E8%A1%8C.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> import baostock as bs
#       <a href='vscode-notebook-cell:/d%3A/HuaweiMoveData/Users/abc/Desktop/LSTM-XGBoost%E6%8B%9B%E5%95%86%E9%93%B6%E8%A1%8C.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> import warnings
#       <a href='vscode-notebook-cell:/d%3A/HuaweiMoveData/Users/abc/Desktop/LSTM-XGBoost%E6%8B%9B%E5%95%86%E9%93%B6%E8%A1%8C.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> code = 'sh.600036'
#
# ModuleNotFoundError: No module named 'baostock'

# %%
df = new_df[['close','high','low','EMA_9','pctChg']].copy()
print(df)
# Out:
#             close   high    low      EMA_9    pctChg
# date
# 2018-01-02  29.62  30.06  29.02        NaN  0.020675
# 2018-01-03  29.97  30.48  29.64  29.620000  0.011816
# 2018-01-04  29.65  30.36  29.40  29.804211 -0.010677
# 2018-01-05  30.10  30.25  29.46  29.747306  0.015177
# 2018-01-08  29.47  30.05  29.31  29.849863 -0.020930
# ...           ...    ...    ...        ...       ...
# 2023-07-26  33.35  33.73  33.07  32.344340  0.002405
# 2023-07-27  33.66  33.82  33.20  32.444906  0.009295
# 2023-07-28  35.10  35.29  33.41  32.566415  0.042781
# 2023-07-31  35.56  36.04  35.01  32.819774  0.013105
# 2023-08-01  34.99  35.58  34.77  33.093796 -0.016029
#
# [1355 rows x 5 columns]

# %%
def Stock_Price_LSTM_Data_Precesing(df,mem_his_days,pre_days):
    df.dropna(inplace=True)
    df.sort_index(inplace=True)

    df['label'] = df['close'].shift(-pre_days)

    from sklearn.preprocessing import StandardScaler
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    sca_X = scaler_x.fit_transform(df.iloc[:,:-1])

    from collections import deque
    deq = deque(maxlen=mem_his_days)

    X = []
    for i in sca_X:
        deq.append(list(i))
        if len(deq)==mem_his_days:
            X.append(list(deq))

    X_lately = X[-pre_days:]
    X = X[:-pre_days]

    y = df['label'].values[mem_his_days-1:-pre_days]
    y = scaler_y.fit_transform(y.reshape(-1, 1))


    import numpy as np
    X = np.array(X)
    y = np.array(y)

    return X, y, X_lately, scaler_y

# %%
print(len(X))
print(len(y))
print(len(X_lately))
# Out:
# 1353
# 1353
# 1

# %%
pre_days = 1
#mem_days = [5,10,15]
#lstm_layers = [1,2,3]
#dense_layers = [1,2,3]
#units = [16,32]
mem_days = [1]
lstm_layers = [1]
dense_layers = [2]
units = [32]
from tensorflow.keras.callbacks import ModelCheckpoint
for the_mem_days in mem_days:
    for the_lstm_layers in lstm_layers:
        for the_dense_layers in dense_layers:
            for the_units in units:
                filepath = '{val_mape:.2f}_{epoch:02d}_'+f'men_{the_mem_days}_lstm_{the_lstm_layers}_dense_{the_dense_layers}_unit_{the_units}'
                checkpoint = ModelCheckpoint(
                    filepath=filepath,
                    save_weights_only=True,
                    monitor='val_mape',
                    mode='min',
                    save_best_only=True)

                X,y,X_lately, scaler_y = Stock_Price_LSTM_Data_Precesing(df,the_mem_days,pre_days)
                from sklearn.model_selection import train_test_split
                X_train, X_test, y_train, y_test = train_test_split(X,y,shuffle=False,test_size=0.3)
                
                import tensorflow as tf
                from tensorflow.keras.models import Sequential
                from tensorflow.keras.layers import LSTM, Dense, Dropout
                model = Sequential()
                model.add(LSTM(the_units,input_shape=X.shape[1:],activation='relu',return_sequences=True))
                model.add(Dropout(0.1))
                
                for i in range(the_lstm_layers):
                    model.add(LSTM(the_units,activation='relu',return_sequences=True))
                    model.add(Dropout(0.1))

                model.add(LSTM(the_units,activation='relu'))
                model.add(Dropout(0.1))

                for i in range(the_dense_layers):
                    model.add(Dense(the_units,activation='relu'))
                    model.add(Dropout(0.1))

                model.add(Dense(1))

                model.compile(optimizer='adam',
                             loss='mse',
                             metrics=['mape'])

                history = model.fit(X_train,y_train,batch_size=32,epochs=50,validation_data=(X_test,y_test),callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 30/30 [==============================] - 3s 21ms/step - loss: 1.1403 - mape: 99.5360 - val_loss: 0.5606 - val_mape: 96.4404
# Epoch 2/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.8321 - mape: 105.6661 - val_loss: 0.2336 - val_mape: 79.2361
# Epoch 3/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1844 - mape: 111.1373 - val_loss: 0.0398 - val_mape: 144.6449
# Epoch 4/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0842 - mape: 112.9558 - val_loss: 0.0353 - val_mape: 135.3019
# Epoch 5/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0743 - mape: 89.8878 - val_loss: 0.0272 - val_mape: 111.5134
# Epoch 6/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0660 - mape: 82.9289 - val_loss: 0.0238 - val_mape: 93.7303
# Epoch 7/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0709 - mape: 88.0142 - val_loss: 0.0237 - val_mape: 95.9478
# Epoch 8/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0651 - mape: 66.7020 - val_loss: 0.0213 - val_mape: 90.8605
# Epoch 9/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0612 - mape: 104.8235 - val_loss: 0.0200 - val_mape: 86.1543
# Epoch 10/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0581 - mape: 83.9140 - val_loss: 0.0210 - val_mape: 85.9741
# Epoch 11/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0631 - mape: 69.3009 - val_loss: 0.0199 - val_mape: 79.2310
# Epoch 12/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0584 - mape: 75.8929 - val_loss: 0.0177 - val_mape: 74.2160
# Epoch 13/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0639 - mape: 70.8543 - val_loss: 0.0211 - val_mape: 79.8320
# Epoch 14/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0545 - mape: 92.8204 - val_loss: 0.0185 - val_mape: 73.0599
# Epoch 15/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0567 - mape: 67.7123 - val_loss: 0.0172 - val_mape: 66.5570
# Epoch 16/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0522 - mape: 87.5034 - val_loss: 0.0195 - val_mape: 67.9790
# Epoch 17/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0530 - mape: 73.1124 - val_loss: 0.0185 - val_mape: 65.0317
# Epoch 18/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0492 - mape: 79.7432 - val_loss: 0.0236 - val_mape: 73.9390
# Epoch 19/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0456 - mape: 66.8116 - val_loss: 0.0249 - val_mape: 74.6200
# Epoch 20/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0493 - mape: 89.5554 - val_loss: 0.0187 - val_mape: 63.0591
# Epoch 21/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0481 - mape: 65.3108 - val_loss: 0.0191 - val_mape: 61.4021
# Epoch 22/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0454 - mape: 89.6776 - val_loss: 0.0183 - val_mape: 58.5768
# Epoch 23/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0500 - mape: 77.8792 - val_loss: 0.0184 - val_mape: 58.0471
# Epoch 24/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0447 - mape: 76.7587 - val_loss: 0.0147 - val_mape: 51.9549
# Epoch 25/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0475 - mape: 76.5630 - val_loss: 0.0170 - val_mape: 56.2469
# Epoch 26/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0462 - mape: 59.8491 - val_loss: 0.0176 - val_mape: 57.6932
# Epoch 27/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0424 - mape: 87.7622 - val_loss: 0.0153 - val_mape: 53.7323
# Epoch 28/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0386 - mape: 63.0924 - val_loss: 0.0198 - val_mape: 61.1559
# Epoch 29/50
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0440 - mape: 87.1296 - val_loss: 0.0148 - val_mape: 51.8483
# Epoch 30/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0442 - mape: 85.5310 - val_loss: 0.0274 - val_mape: 77.4783
# Epoch 31/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0402 - mape: 59.5139 - val_loss: 0.0196 - val_mape: 64.5315
# Epoch 32/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0391 - mape: 63.9626 - val_loss: 0.0186 - val_mape: 65.0305
# Epoch 33/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0397 - mape: 60.4550 - val_loss: 0.0201 - val_mape: 68.4550
# Epoch 34/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0408 - mape: 74.1891 - val_loss: 0.0174 - val_mape: 62.5174
# Epoch 35/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0404 - mape: 59.5479 - val_loss: 0.0162 - val_mape: 65.1298
# Epoch 36/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0394 - mape: 82.3731 - val_loss: 0.0192 - val_mape: 64.7003
# Epoch 37/50
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0378 - mape: 52.6702 - val_loss: 0.0157 - val_mape: 55.5790
# Epoch 38/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0382 - mape: 47.5613 - val_loss: 0.0155 - val_mape: 59.2139
# Epoch 39/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0370 - mape: 71.1188 - val_loss: 0.0145 - val_mape: 52.4470
# Epoch 40/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0379 - mape: 86.1432 - val_loss: 0.0142 - val_mape: 50.0291
# Epoch 41/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0319 - mape: 66.1540 - val_loss: 0.0146 - val_mape: 57.3734
# Epoch 42/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0379 - mape: 56.7844 - val_loss: 0.0148 - val_mape: 52.4002
# Epoch 43/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0382 - mape: 48.4720 - val_loss: 0.0169 - val_mape: 55.5964
# Epoch 44/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0367 - mape: 70.6042 - val_loss: 0.0140 - val_mape: 54.1553
# Epoch 45/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0375 - mape: 100.6759 - val_loss: 0.0161 - val_mape: 56.4836
# Epoch 46/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0402 - mape: 54.7642 - val_loss: 0.0165 - val_mape: 56.7480
# Epoch 47/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0354 - mape: 60.7643 - val_loss: 0.0168 - val_mape: 55.1362
# Epoch 48/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0337 - mape: 65.0249 - val_loss: 0.0147 - val_mape: 50.7072
# Epoch 49/50
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0376 - mape: 56.5598 - val_loss: 0.0156 - val_mape: 54.4835
# Epoch 50/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0341 - mape: 72.7741 - val_loss: 0.0143 - val_mape: 51.7314

# %%
# Display training process
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])

# %%
model.evaluate(X_test,y_test)
# Out:
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0143 - mape: 51.7314
# [0.0142955482006073, 51.73140335083008]

# %%
pre = model.predict(X_test)
print(len(pre))

import matplotlib.pyplot as plt
plt.figure(figsize=(15, 6))
df_time = df.index[-len(y_test):]
plt.plot(df_time,y_test,color='blue',label='price')
plt.plot(df_time,pre,color='orange',label='predict')
plt.legend(labels=['close', 'predictions'])
plt.xticks(df_time[::20], rotation = 45)
plt.show()
# Out:
# 13/13 [==============================] - 0s 2ms/step
# 406

# %%
# Predict all slices in the test set in a sequential manner, and check the fit between the predicted results and the true values

pre_invscaled = scaler_y.inverse_transform(pre)
y_test_invscaled = scaler_y.inverse_transform(y_test)
plt.figure(figsize=(15, 6))
df_time = df.index[-len(y_test):]
plt.plot(df_time,y_test_invscaled,color='blue',label='price')
plt.plot(df_time,pre_invscaled,color='orange',label='predict')
plt.xticks(df_time[::20], rotation = 45)
plt.legend(labels=['close', 'predictions'])
plt.xticks (np.arange (0, 451, 50), np.arange (0, 451, 50))
plt.figure(dpi=500)
plt.show()

# %%
#calculate MSE, RMSE
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(pre_invscaled, y_test_invscaled)
rmse = np.sqrt(mse) 
mape = np.mean(np.abs((pre_invscaled - y_test_invscaled) / pre_invscaled)) * 100
from sklearn.metrics import mean_absolute_error
import numpy as np
mae = mean_absolute_error(pre_invscaled, y_test_invscaled)
rmae = np.sqrt(mae)
from sklearn.metrics import r2_score
r2 = r2_score(y_test_invscaled, pre_invscaled)
# Assuming a threshold of 0.1
threshold = 0.1
# Calculate the absolute difference between predicted and true values
diff = np.abs(pre_invscaled - y_test_invscaled)
# Determine if the difference is less than the threshold
correct = diff < threshold
# Calculate accuracy
accuracy = np.mean(correct)
print('MSE of Prediction: ', mse, '\n')
print('RMSE of Prediction: ', rmse)
print('MAPE of Prediction: ', mape)
print('RMAE of Prediction: ', rmae)
print('R^2 of Prediction: ', r2)
print('Accuracy of Prediction: ', accuracy)
# Out:
# LSTM预测结果的MSE：  0.9691323730803163
#
# LSTM预测结果的RMSE：  0.9844452108067346
# LSTM预测结果的MAPE：  1.9335951932208293
# LSTM预测结果的RMAE：  0.8611295018829647
# LSTM预测结果的R^2：  0.9764972286063539
# LSTM预测结果的Accuracy：  0.09113300492610837
